# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import scipy.stats as sc
import csv
import seaborn as sns

# %%
file_2015 = "Data/datasets_894_813759_2015.csv"
file_2016 = "Data/datasets_894_813759_2016.csv"
file_2017 = "Data/datasets_894_813759_2017.csv"
file_2018 = "Data/datasets_894_813759_2018.csv"
file_2019 = "Data/datasets_894_813759_2019.csv"

df_2015 = pd.read_csv(file_2015)
df_2016 = pd.read_csv(file_2016)
df_2017 = pd.read_csv(file_2017)
df_2018 = pd.read_csv(file_2018)
df_2019 = pd.read_csv(file_2019)
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
 # Create data frame. The last column is the needed color
#          df = pd.DataFrame(np.random.random((100,2)), columns=["x","y"])
# Add a column: the color depends of x and y values, but you can use whatever function.
#         value=(df['x']>0.2) & (df['y']>0.4)
#         df['color']= np.where( value==True , "#9b59b6", "#3498db")
 
# plot
#        sns.regplot(data=df, x="x", y="y", fit_reg=False, scatter_kws={'facecolors':df['color']})
#sns.plt.show()

# %%
df_2015.head()
Top2015_df = df_2015.rename (columns = {"Happiness Rank":"Rank", "Happiness Score":"Score", "Economy (GDP per Capita)":"GDP_per_Capita", "Health (Life Expectancy)": "Life_Expectancy", "Trust (Government Corruption)": "Corruption", "Dystopia Residual":"Dystopia"})
Top2015_df.drop(["Region", "Family", "Dystopia", "Standard Error"], axis = 1, inplace = True)
Top2015_df['Year']=2015
Top2015_df = Top2015_df.round(2)
df = pd.DataFrame(Top2015_df)
Top2015_df.head()
# Out:
#        Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 0  Switzerland     1   7.59            1.40             0.94     0.67
# 1      Iceland     2   7.56            1.30             0.95     0.63
# 2      Denmark     3   7.53            1.33             0.87     0.65
# 3       Norway     4   7.52            1.46             0.89     0.67
# 4       Canada     5   7.43            1.33             0.91     0.63
#
#    Corruption  Generosity  Year
# 0        0.42        0.30  2015
# 1        0.14        0.44  2015
# 2        0.48        0.34  2015
# 3        0.37        0.35  2015
# 4        0.33        0.46  2015

# %%
# Create data frame. The last column is the needed color
#       
# Add a column: the color depends of x and y values, but you can use whatever function.
#         value=(df['x']>0.2) & (df['y']>0.4)
#         df['color']= np.where( value==True , "#9b59b6", "#3498db")
# plot
#        sns.regplot(data=df, x="x", y="y", fit_reg=False, scatter_kws={'facecolors':df['color']})
#sns.plt.show()

# %%
#df = pd.DataFrame(np.random.random((100,2)), columns=["Freedom","Year"])
#value=(df['Freedom']>0.2) & (df['Year']>0.4)
#df['color']= np.where( value==True , "#9b59b6", "#3498db")
#sns.regplot(data=df, x="Freedom", y="Score", fit_reg=False, scatter_kws={'facecolors':df['color']})
#sns.plt.show()

# %%
df_2016.head()
Top2016_df = df_2016.rename (columns = {"Happiness Rank":"Rank", "Happiness Score": "Score", "Economy (GDP per Capita)":"GDP_per_Capita", "Health (Life Expectancy)": "Life_Expectancy", "Trust (Government Corruption)": "Corruption", "Dystopia Residual": "Dystopia"})
Top2016_df.drop(["Region", "Lower Confidence Interval", "Dystopia", "Family", "Upper Confidence Interval"], axis = 1, inplace = True)
Top2016_df['Year']=2016
Top2016_df = Top2016_df.round(2)
#Top2016_df['GDP per Capita'] = Top2016_df['GDP per Capita'].round(2) 
Top2016_df.head()
# Out:
#        Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 0      Denmark     1   7.53            1.44             0.80     0.58
# 1  Switzerland     2   7.51            1.53             0.86     0.59
# 2      Iceland     3   7.50            1.43             0.87     0.57
# 3       Norway     4   7.50            1.58             0.80     0.60
# 4      Finland     5   7.41            1.41             0.81     0.57
#
#    Corruption  Generosity  Year
# 0        0.44        0.36  2016
# 1        0.41        0.28  2016
# 2        0.15        0.48  2016
# 3        0.36        0.38  2016
# 4        0.41        0.25  2016

# %%
#df = pd.DataFrame(np.random.random((100,2)), columns=["Freedom","Score"])
#value=(df['Freedom']>0.2) & (df['Score']>0.4)
#df['color']= np.where( value==True , "#9b59b6", "#3498db")
#sns.regplot(data=df, x="Freedom", y="Score", fit_reg=False, scatter_kws={'facecolors':df['color']})
#sns.plt.show()

#Ask Richa if i am on  right path

# %%
Top2017_df = df_2017.rename (columns = {"Happiness.Rank": "Rank", "Happiness.Score":"Score", "Economy..GDP.per.Capita.":"GDP_per_Capita", "Health..Life.Expectancy.": "Life_Expectancy", "Trust..Government.Corruption.": "Corruption"})
Top2017_df.drop(["Whisker.high", "Family", "Dystopia.Residual", "Whisker.low"], axis = 1, inplace = True)
Top2017_df['Year']=2017
df = pd.DataFrame(Top2017_df) 
Top2017_df = Top2017_df.round(2)
Top2017_df.head()
# Out:
#        Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 0       Norway     1   7.54            1.62             0.80     0.64
# 1      Denmark     2   7.52            1.48             0.79     0.63
# 2      Iceland     3   7.50            1.48             0.83     0.63
# 3  Switzerland     4   7.49            1.56             0.86     0.62
# 4      Finland     5   7.47            1.44             0.81     0.62
#
#    Generosity  Corruption  Year
# 0        0.36        0.32  2017
# 1        0.36        0.40  2017
# 2        0.48        0.15  2017
# 3        0.29        0.37  2017
# 4        0.25        0.38  2017

# %%
df_2018.head()
Top2018_df = df_2018.rename (columns = {"Overall rank": "Rank","Country or region": "Country","GDP per capita": "GDP_per_Capita","Social support": "Social_Support", "Healthy life expectancy": "Life_Expectancy", "Freedom to make life choices": "Freedom", "Perceptions of corruption": "Corruption"})
Top2018_df['Year']=2018
df = pd.DataFrame(Top2018_df) 
Top2018_df = Top2018_df.round(2)
Top2018_df.head()
# Out:
#    Rank      Country  Score  GDP_per_Capita  Social_Support  Life_Expectancy  \
# 0     1      Finland   7.63            1.30            1.59             0.87
# 1     2       Norway   7.59            1.46            1.58             0.86
# 2     3      Denmark   7.56            1.35            1.59             0.87
# 3     4      Iceland   7.50            1.34            1.64             0.91
# 4     5  Switzerland   7.49            1.42            1.55             0.93
#
#    Freedom  Generosity  Corruption  Year
# 0     0.68        0.20        0.39  2018
# 1     0.69        0.29        0.34  2018
# 2     0.68        0.28        0.41  2018
# 3     0.68        0.35        0.14  2018
# 4     0.66        0.26        0.36  2018

# %%
df_2019.head()
Top2019_df = df_2018.rename (columns = {"Overall rank": "Rank", "Country or region": "Country", "GDP per capita": "GDP_per_Capita", "Social support":"Social_Support", "Healthy life expectancy": "Life_Expectancy", "Freedom to make life choices": "Freedom", "Perceptions of corruption": "Corruption"})
Top2019_df['Year']=2019
df = pd.DataFrame(Top2019_df) 
Top2019_df = Top2019_df.round(2)
Top2019_df.head()
# Out:
#    Rank      Country  Score  GDP_per_Capita  Social_Support  Life_Expectancy  \
# 0     1      Finland   7.63            1.30            1.59             0.87
# 1     2       Norway   7.59            1.46            1.58             0.86
# 2     3      Denmark   7.56            1.35            1.59             0.87
# 3     4      Iceland   7.50            1.34            1.64             0.91
# 4     5  Switzerland   7.49            1.42            1.55             0.93
#
#    Freedom  Generosity  Corruption  Year
# 0     0.68        0.20        0.39  2019
# 1     0.69        0.29        0.34  2019
# 2     0.68        0.28        0.41  2019
# 3     0.68        0.35        0.14  2019
# 4     0.66        0.26        0.36  2019

# %%
#df_happyness_2015_2016 = pd.concat([Top2015_df, Top2016_df])
#df_happyness_2015_2016_2017 = pd.concat([df_happyness_2015_2016, Top2017_df])
#df_happyness_2015_2016_2017_2018 = pd.concat([df_happyness_2015_2016_2017,Top2018_df])
#df_happyness = pd.concat([df_happyness_2015_2016_2017_2018,Top2019_df])
#df_happyness.head()

# %%
df_happyness_2015_2016 = pd.concat([Top2015_df, Top2016_df])
df_happyness_2015_2016
# Out:
#          Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 0    Switzerland     1   7.59            1.40             0.94     0.67
# 1        Iceland     2   7.56            1.30             0.95     0.63
# 2        Denmark     3   7.53            1.33             0.87     0.65
# 3         Norway     4   7.52            1.46             0.89     0.67
# 4         Canada     5   7.43            1.33             0.91     0.63
# ..           ...   ...    ...             ...              ...      ...
# 152        Benin   153   3.48            0.39             0.21     0.40
# 153  Afghanistan   154   3.36            0.38             0.17     0.16
# 154         Togo   155   3.30            0.28             0.25     0.35
# 155        Syria   156   3.07            0.75             0.63     0.07
# 156      Burundi   157   2.90            0.07             0.16     0.04
#
#      Corruption  Generosity  Year
# 0          0.42        0.30  2015
# ...

# %%
df_happyness_2015_2016_2017 = pd.concat([df_happyness_2015_2016, Top2017_df])
df_happyness_2015_2016_2017
# Out:
#                       Country  Rank  Score  GDP_per_Capita  Life_Expectancy  \
# 0                 Switzerland     1   7.59            1.40             0.94
# 1                     Iceland     2   7.56            1.30             0.95
# 2                     Denmark     3   7.53            1.33             0.87
# 3                      Norway     4   7.52            1.46             0.89
# 4                      Canada     5   7.43            1.33             0.91
# ..                        ...   ...    ...             ...              ...
# 150                    Rwanda   151   3.47            0.37             0.33
# 151                     Syria   152   3.46            0.78             0.50
# 152                  Tanzania   153   3.35            0.51             0.36
# 153                   Burundi   154   2.90            0.09             0.15
# 154  Central African Republic   155   2.69            0.00             0.02
#
#      Freedom  Corruption  Generosity  Year
# ...

# %%
df_happyness_2015_2016_2017_2018 = pd.concat([df_happyness_2015_2016_2017,Top2018_df])
df_happyness_2015_2016_2017_2018
# Out:
#                       Country  Rank  Score  GDP_per_Capita  Life_Expectancy  \
# 0                 Switzerland     1   7.59            1.40             0.94
# 1                     Iceland     2   7.56            1.30             0.95
# 2                     Denmark     3   7.53            1.33             0.87
# 3                      Norway     4   7.52            1.46             0.89
# 4                      Canada     5   7.43            1.33             0.91
# ..                        ...   ...    ...             ...              ...
# 151                     Yemen   152   3.36            0.44             0.34
# 152                  Tanzania   153   3.30            0.46             0.38
# 153               South Sudan   154   3.25            0.34             0.18
# 154  Central African Republic   155   3.08            0.02             0.01
# 155                   Burundi   156   2.90            0.09             0.14
#
# ...

# %%
df_happyness = pd.concat([df_happyness_2015_2016_2017_2018,Top2019_df])
df_happyness
# Out:
#                       Country  Rank  Score  GDP_per_Capita  Life_Expectancy  \
# 0                 Switzerland     1   7.59            1.40             0.94
# 1                     Iceland     2   7.56            1.30             0.95
# 2                     Denmark     3   7.53            1.33             0.87
# 3                      Norway     4   7.52            1.46             0.89
# 4                      Canada     5   7.43            1.33             0.91
# ..                        ...   ...    ...             ...              ...
# 151                     Yemen   152   3.36            0.44             0.34
# 152                  Tanzania   153   3.30            0.46             0.38
# 153               South Sudan   154   3.25            0.34             0.18
# 154  Central African Republic   155   3.08            0.02             0.01
# 155                   Burundi   156   2.90            0.09             0.14
#
# ...

# %%
#plt.scatter (x, y)
#plt.annotate(line_eq,/0,50), fontsize=15,color= "red")
#plt.annotate(fontsize=15, color="red")

# %%
#https://stackoverflow.com/questions/43482446/python-scatter-plot-different-colors-depending-on-value

# %%
plt.scatter(df_happyness.Freedom, df_happyness.Score) #, s=df_happyness.Year)
x=df_happyness["Freedom"]
y=df_happyness["Score"]
sns.regplot(x, y)#
g = sns.jointplot(x, y)
sns.regplot(x="Freedom", y="Score", data=df_happyness,color="Year", line_kws={'color': 'red'} )
regline = g.ax_joint.get_lines()[0]
regline.set_color('red')
plt.title("Happiness vs. Freedom")
plt.ylabel("Happiness Score")
plt.xlabel("Freedom")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-fcd07aa6a692> in <module>
#       4 sns.regplot(x, y)#
#       5 g = sns.jointplot(x, y)
# ----> 6 sns.regplot(x="Freedom", y="Score", data=df_happyness,color="Year", line_kws={'color': 'red'} )
#       7 regline = g.ax_joint.get_lines()[0]
#       8 regline.set_color('red')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# ...

# %%
g =sns.scatterplot(x="Freedom", y="Score",
              hue="Year",
              data=df_happyness);
g.set(xscale="log"); sns.regplot(x='Freedom', y='Score', color='r')
plt.plot(df_happyness["Freedom", "Score"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-1c1213d90175> in <module>
#       2               hue="Year",
#       3               data=df_happyness);
# ----> 4 g.set(xscale="log"); sns.regplot(x='Freedom', y='Score', color='r')
#       5 plt.plot(df_happyness["Freedom", "Score"])
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     808                                  order, logistic, lowess, robust, logx,
#     809                                  x_partial, y_partial, truncate, dropna,
# --> 810                                  x_jitter, y_jitter, color, label)
#     811
# ...

# %%
df_happyness = pd.concat([df_happyness_2015_2016_2017_2018,Top2019_df])


data = df_happyness(df_happyness.data, columns=Freedom)
data['Freedom'] = df_happyness.data.target
print (df_happyness.data).Descr

x_values =df_happyness['Freedom']
y_values =df_happyness['Score']
slope, intercept, rvalue, pvalue, stderr= lineregress(x_values, y_values)
regress_values= x_values*slope+intercept
line_eq="y="+ str(round(slope,2)) + "x+"+str(round(intercept,2)

#plt.scatter(x_values, y_values)
#plt.plot (regress_values, "-r")
#plt.annotate(line_eq,/0,50), fontsize=15,color="red")
#plt.annotate(f"The r-squared is:{round(rvalue**2,2)}", (0,20), fontsize=15, color ="red")
#plt.annotate(f"The correlation is:{round(rvalue,2)}", (0,70, fontsize =15, color "Y")
#plt.xlabel('Freedom')
#plt.ylabel('Score')
#plt.show()    AQUI YA NO SE LO QUE ESTOY HACIENDO    :(   HELP  !!!)
# Out:
#   File "<ipython-input-81-a222f70e258c>", line 21
#     #plt.show()
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
sns.regplot(x='Freedom', y= 'Score', data = df_happyness, color= 'y')

# %%
plt.scatter(df_happyness.Generosity, df_happyness.Score)
plt.title("Happiness vs. Generosity")
plt.ylabel("Hapiness Score")
plt.xlabel("Generosity")
# Out:
# Text(0.5, 0, 'Generosity')

# %%
g =sns.scatterplot(x="Generosity", y="Score",
              hue="Year",
              data=df_happyness);
g.set(xscale="log");
plt.plot(df_happyness["Generosity", "Score"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Generosity', 'Score')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-7cf3d72decb7> in <module>
# ...

# %%
#plt.scatter(df_happyness.Score, df_happyness.Corruption)
#plt.xlim (0,8)
#plt.ylim (-1,1)
plt.scatter(df_happyness.Corruption, df_happyness.Score)
plt.title("Happiness vs. Corruption")
plt.ylabel("Hapiness Score")
plt.xlabel("Corruption")
# Out:
# Text(0.5, 0, 'Corruption')

# %%
#plt.scatter(df_happyness.Score, df_happyness.GDP_per_Capita)
#plt.xlim (0,8)
#plt.ylim (-1,1)
plt.scatter(df_happyness.GDP_per_Capita, df_happyness.Score)
plt.title("Happiness vs. GDP per Capita")
plt.ylabel("Hapiness Score")
plt.xlabel("GDP per Capita")
# Out:
# Text(0.5, 0, 'GDP per Capita')

# %%
plt.scatter(df_happyness.Life_Expectancy, df_happyness.Score)
#plt.xlim (0,8)
#plt.ylim (-1,1)
plt.title("Happiness vs. Life Expectancy")
plt.ylabel("Hapiness Score")
plt.xlabel("Life Expectancy")
# Out:
# Text(0.5, 0, 'Life Expectancy')

# %%
#(slope, intercept, _, _, _) = linregress(x_axis, fake)
#fit = slope * x_axis + intercept
#(slope, intercept, _, _, _) = linregress(x_axis, fake)
#fit = slope * df_happyness + intercept

# %%
lins =  sc.linregress(df_happyness["Score"],df_happyness["Freedom"])
#fit = slope * x_axis + intercept
lins
# Out:
# LinregressResult(slope=0.07602274939354947, intercept=0.014935624290930871, rvalue=0.5462447602712969, pvalue=4.966251607533301e-62, stderr=0.00417406236427784)

# %%
lins =  sc.linregress(df_happyness["Score"],df_happyness["GDP_per_Capita"])
#fit = slope * x_axis + intercept
lins
# Out:
# LinregressResult(slope=0.2846214097471928, intercept=-0.6159075438196011, rvalue=0.7908421894783381, pvalue=1.7162452893000666e-168, stderr=0.007886714803538551)

# %%
lins =  sc.linregress(df_happyness["Score"],df_happyness["Life_Expectancy"])
#fit = slope * x_axis + intercept
lins
# Out:
# LinregressResult(slope=0.16342935736425063, intercept=-0.2910359069814228, rvalue=0.7587866060043312, pvalue=2.2126238067116575e-147, stderr=0.005023083527515097)

# %%
lins =  sc.linregress(df_happyness["Score"],df_happyness["Generosity"])
#fit = slope * x_axis + intercept
lins
# Out:
# LinregressResult(slope=0.0161300880872172, intercept=0.13114996624127376, rvalue=0.14806475999505694, pvalue=3.2269234982632126e-05, stderr=0.003857662377191052)

# %%
from scipy.stats import pearsonr
pearsonr(df_happyness["Score"],df_happyness["Generosity"])
# Out:
# (0.148064759995057, 3.226923498262997e-05)

# %%
#lins =  sc.linregress(df_happyness["Score"],df_happyness["Corruption"])
#fit = slope * x_axis + intercept
mask = ~np.isnan( df_happyness["Score"]) & ~np.isnan(df_happyness["Corruption"])
sc.linregress(varx[mask], vary[mask])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-2b29a6afc0f8> in <module>
#       2 #fit = slope * x_axis + intercept
#       3 mask = ~np.isnan( df_happyness["Score"]) & ~np.isnan(df_happyness["Corruption"])
# ----> 4 sc.linregress(varx[mask], vary[mask])
#
# NameError: name 'varx' is not defined

# %%
#gyms = ["Crunch", "Planet Fitness", "NY Sports Club", "Rickie's Gym"]
#members = [49, 92, 84, 53]
#plt.bar(x_axis, members, facecolor="red", alpha=0.75, align="center")

# %%
x_axis = ["Freedom","GDP","Life Expectancy","Generosity","Corruption"]
y_axis = [0.546, 0.791, 0.759, 0.148, 0.402]
plt.bar(x_axis, y_axis, facecolor="red", alpha=0.75, align="center")
#plt.xlim(-0.75, len(x_axis)-1)
#plt.ylim(0,(y_axis)-1)
#hablar con K
plt.ylim(0, max(y_axis)+0.5)
# Out:
# (0, 1.291)

# %%
df_2015.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
#averiguar como obtengo mas paises....con la coma....o que?.....OJO
df_2015
LatinCountries_df= Top2015_df.loc[df_2015["Country"]=="Ecuador"]
LatinCountries_df
# Out:
#     Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 47  Ecuador    48   5.98            0.86             0.79     0.49
#
#     Corruption  Generosity  Year
# 47        0.18        0.12  2015

# %%
Top2015_df
NAregion15_df=Top2015_df.loc[df_2015["Region"]=="North America"]
NAregion15_df
# Out:
#           Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 4          Canada     5   7.43            1.33             0.91     0.63
# 14  United States    15   7.12            1.39             0.86     0.55
#
#     Corruption  Generosity  Year
# 4         0.33        0.46  2015
# 14        0.16        0.40  2015

# %%
Top2016_df
NAregion16_df=Top2016_df.loc[df_2016["Region"]=="North America"]
NAregion16_df
# Out:
#           Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 5          Canada     6    7.4            1.44             0.83     0.57
# 12  United States    13    7.1            1.51             0.78     0.48
#
#     Corruption  Generosity  Year
# 5         0.31        0.45  2016
# 12        0.15        0.41  2016

# %%
Top2017_df
NAregion17_df=Top2017_df.loc[df_2017["Region"]=="North America"]
NAregion17_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-7cce8f76e9fd> in <module>
#       1 Top2017_df
# ...

# %%
Top2018_df
NAregion18_df=Top2018_df.loc[df_2018["Region"]=="North America"]
NAregion18_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-47edcd4d25ef> in <module>
#       1 Top2018_df
# ...

# %%
Top2019_df
NAregion19_df=Top2019_df.loc[df_2019["Region"]=="North America"]
NAregion19_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-1db8ac81d5c3> in <module>
#       1 Top2019_df
# ...

# %%
Top2015_df
WEregion15_df=Top2015_df.loc[df_2015["Region"]=="Western Europe"]
WEregion15_df.head()
# Out:
#        Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 0  Switzerland     1   7.59            1.40             0.94     0.67
# 1      Iceland     2   7.56            1.30             0.95     0.63
# 2      Denmark     3   7.53            1.33             0.87     0.65
# 3       Norway     4   7.52            1.46             0.89     0.67
# 5      Finland     6   7.41            1.29             0.89     0.64
#
#    Corruption  Generosity  Year
# 0        0.42        0.30  2015
# 1        0.14        0.44  2015
# 2        0.48        0.34  2015
# 3        0.37        0.35  2015
# 5        0.41        0.23  2015

# %%
Top2016_df
WEregion16_df=Top2016_df.loc[df_2016["Region"]=="Western Europe"]
WEregion16_df.head()
# Out:
#        Country  Rank  Score  GDP_per_Capita  Life_Expectancy  Freedom  \
# 0      Denmark     1   7.53            1.44             0.80     0.58
# 1  Switzerland     2   7.51            1.53             0.86     0.59
# 2      Iceland     3   7.50            1.43             0.87     0.57
# 3       Norway     4   7.50            1.58             0.80     0.60
# 4      Finland     5   7.41            1.41             0.81     0.57
#
#    Corruption  Generosity  Year
# 0        0.44        0.36  2016
# 1        0.41        0.28  2016
# 2        0.15        0.48  2016
# 3        0.36        0.38  2016
# 4        0.41        0.25  2016

# %%
Top2017_df
WEregion17_df=Top2017_df.loc[df_2017["Region"]=="Western Europe"]
WEregion17_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-d4077c8d0c3f> in <module>
#       1 Top2017_df
# ...

# %%
Top2018_df
WEregion18_df=Top2018_df.loc[df_2018["Region"]=="Western Europe"]
WEregion18_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-024564884338> in <module>
#       1 Top2018_df
# ...

# %%
Top2019_df
WEregion19_df=Top2016_df.loc[df_2019["Region"]=="Western Europe"]
WEregion19_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-db383c01f566> in <module>
#       1 Top2019_df
# ...

# %%
Top2015_df
ANZregion15_df=Top2015_df.loc[df_2015["Region"]=="Australia and New Zealand"]
ANZregion15_df

# %%
Top2015_df
MENAregion15_df=Top2015_df.loc[df_2015["Region"]=="Middle East and Northern Africa"]
MENAregion15_df

# %%
Top2015_df
SEAregion15_df=Top2015_df.loc[df_2015["Region"]=="Southeastern Asia"]
SEAregion15_df

# %%
Top2015_df
CEEregion15_df=Top2015_df.loc[df_2015["Region"]=="Central and Eastern Europe"]
CEEregion15_df

# %%
Top2015 = Top2015_df[["Country","Score", "Year"]].copy()[:5]
Top2015

#new = old[['A', 'C', 'D']].copy()

# %%
Top2016 = Top2016_df[["Country","Score","Year"]].copy().head()
Top2016

# %%
df_happyness_2015_2016 = pd.concat([Top2015, Top2016])
df_happyness_2015_2016

# %%
df_happyness_2015_2016.groupby(['Country'])["Score"].mean().plot(kind = 'bar')

# %%
df_happyness_2015_2016.groupby(['Country']).nunique()['Score'].plot(kind = 'bar')
